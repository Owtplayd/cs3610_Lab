# %% [markdown]
# # Design Patterns Module - Assignment 1. Creational Patterns

# %% [markdown]
# ## Task 1. Implementing **Factory Method** in Python - 10 points

# %% [markdown]
# 1. Imagine that you need to develop a simple application to display data about animals living in a zoo.
# "Display" here means asking the animal to say something.
# * *lions* -> `say() `looks like *Roaring*
# * *elephants ' -> `say() `looks like *trumpet*
# * etc.
# 2. However, different zoos have different animals and different itineraries for visitors
# * Toronto Zoo:
# * * has lions, elephants, penguins, white bears
# * * its Itinerary looks like "Welcome to the Toronto Zoo! Our Itinerary: 1) African Savanna. 2) Tundra Trek"
# Develop a simple application that generates different types of documents (e.g., Word, PDF) using the Factory Method pattern (see the Class Diagram below).
#
# * Calgary  Zoo:
# * * has grizzly bears, moose, penguins
# * * its Itinerary looks like "Welcome to the Toronto Zoo! Our Itinerary: 1) Penguin Plunge. 2)  Wild Canad"
#
#
# 3. Use the following UML Diagram to apply factory method Pattern to develop the required Apps.

# %% [markdown]
# ![image.png](attachment:image.png)
